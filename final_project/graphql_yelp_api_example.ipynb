# %% [markdown]
# # Querying Yelp using GraphQL
# This is a beta program, but contrary to the other Yelp APIs, allows us to completely customize our querys, only obtaining the data we'll need for our analysis.
#
# Below is an example of how to utilize the `GraphQL` Yelp API to query 10 coffee shops in Brooklyn 11222 postal code.
#
# For detailed instructions please reference [Getting Started with Yelp GraphQL](https://docs.developer.yelp.com/docs/graphql-intro)

# %%
# import packages
import requests
import pandas as pd
import sys
sys.path.append('src') # add src folder to path

# import api key
from config import YELP_API

# %% [markdown]
# First we need to set our `headers` and `url`.<br>
# The API key needs to be approved for beta use, so prior to making any queries, goto the `Manage Account` section of your Yelp profile and approve for beta use.

# %%
# set up headers and access token
headers = {
    "Authorization": f"Bearer {YELP_API}",
    "Content-Type": "application/json"
}

# set url
url = "https://api.yelp.com/v3/graphql"

# %% [markdown]
# Next we perform the business query.<br>
# We don't want to query the reviews yet, because we have a **one-to-many relationship**, meaning we will have multiple reviews for each business (limiting to 5 in this demo).

# %%
# basic query
businesses_query = """
{
  search(location: "Brooklyn 11222", categories: "coffee", limit: 10) {
    business {
      id
      name
      rating
      review_count
    }
  }
}
"""

# %% [markdown]
# We make the API call with the `requests` package passing the query and the headers for authentication.<br>
# After this we convert the response to json, this will allow us to smoothly parse into lists and eventually dataframes.

# %%
# api call to fetch businesses
response = requests.post(url, json={"query": businesses_query}, headers=headers)
data = response.json()

# %%
# extract info
businesses = data["data"]["search"]["business"]

# data storage lists
business_data = []
review_data = []

# iterate over the businesses and fetch their reviews
for business in businesses:
    # fetch reviews for the current business
    reviews_query = f"""
    {{
      business(id: "{business['id']}") {{
        reviews(limit: 5) {{
          user {{
            name
            id
          }}
          rating
          text
        }}
      }}
    }}
    """
    # api call to fetch reviews
    reviews_response = requests.post(url, json={"query": reviews_query}, headers=headers)
    reviews_data = reviews_response.json()
    
    # extract info
    reviews = reviews_data["data"]["business"]["reviews"]

    # store business data
    business_data.append({
        "business_id": business["id"],
        "business_name": business["name"],
        "rating": business["rating"],
        "review_count": business["review_count"]
    })

    # store review data
    for review in reviews:
        review_data.append({
            "business_id": business["id"],
            "review_user_id":review["user"]["id"],
            "review_user": review["user"]["name"],
            "review_rating": review["rating"],
            "review_text": review["text"]
        })

# %% [markdown]
# Create two dataframes:
# - one for businesses
# - one for reviews
#
# Having separate dataframes will allow us to explore the **one-to-many** relationship between business and reviews.

# %%
# business df
business_df = pd.DataFrame(business_data)

# reviews df
review_df = pd.DataFrame(review_data)

# %% [markdown]
# Look at contents

# %%
business_df
# Out:
#               business_id            business_name  rating  review_count
# 0  1Q3oaJahyGRogDWgpo7PIw              Five Leaves     4.0          1726
# 1  kpxXi23lUQkeJQH-2BtzDw             Qahwah House     4.5           355
# 2  s1pJHjoce-IbHQiCe4mA3w  Martha's Country Bakery     4.5           993
# 3  UpPXAjKc-CyuCg72chwd3A         Lella Alimentari     4.5           237
# 4  YpGxtJy9ErnjfGG6DXy5uA              Coffee Shop     4.5           376
# 5  VdAVjghEq_Zl-DDte0mjrw                     ACRE     4.5           109
# 6  AfZPx4piTmg9dqZpYgYTgg  Moe's Doughs Donut Shop     4.5           374
# 7  QaDOWy4-11982JWIxpImNQ   Little Choc Apothecary     4.5           546
# 8  qXuUBEaib4caLC6WCPhBjA        Patisserie Tomoko     4.5           413
# 9  k17DEW9TqRZf6EFSc49OsA                   Bakeri     4.0           407

# %%
review_df
# Out:
#                business_id          review_user_id   review_user  \
# 0   1Q3oaJahyGRogDWgpo7PIw  FvHYaxYF6mAw67dv_z35Rg        Ava B.
# 1   1Q3oaJahyGRogDWgpo7PIw  Sk9smcO5GeU1rY91DrFVew   Marykate M.
# 2   1Q3oaJahyGRogDWgpo7PIw  2M2GdA9HzcXI5cqECZDqgg     Brandi I.
# 3   kpxXi23lUQkeJQH-2BtzDw  lGZ1juew09lxLRDYAmdtjg     Sophia C.
# 4   kpxXi23lUQkeJQH-2BtzDw  zeTbYRLUK70R_3thy_L26A       Theo W.
# 5   kpxXi23lUQkeJQH-2BtzDw  ZdVhjBEiZvuuGcHHjIt6bA  Nichakorn C.
# 6   s1pJHjoce-IbHQiCe4mA3w  SYXe1HJXcRKN8lgtBXPhfA     Sofyan S.
# 7   s1pJHjoce-IbHQiCe4mA3w  -CQO2sipbY360zwPU_eJsA      Abiba S.
# 8   s1pJHjoce-IbHQiCe4mA3w  4xxctThQAQYwb8Ntv17JCw    Michele B.
# 9   UpPXAjKc-CyuCg72chwd3A  -yEhhXT6URxh_yxHko5Gzg       Alan S.
# 10  UpPXAjKc-CyuCg72chwd3A  v6DXW3BA0C4TEqAmbLPFEQ    Alberto G.
# 11  UpPXAjKc-CyuCg72chwd3A  bPBMw2DFQnKfNXGItUWmkg  Aishwarya S.
# 12  YpGxtJy9ErnjfGG6DXy5uA  V4hps9YOcKeQry_jgGvHiw       Kaya E.
# 13  YpGxtJy9ErnjfGG6DXy5uA  MLbHeXL6S2M1daO3R15SJg    Eugenia Y.
# 14  YpGxtJy9ErnjfGG6DXy5uA  QhyZLzaMAe5Yw6kz9tWmgQ      Sarah R.
# 15  VdAVjghEq_Zl-DDte0mjrw  3nPEsH_YlQJMFrNJFAjmfQ        Amy D.
# 16  VdAVjghEq_Zl-DDte0mjrw  lAOkhe0OG_hH39bFLlmxaA      Kevin C.
# 17  VdAVjghEq_Zl-DDte0mjrw  bd0okEGblYceUqC9f9uTcg       Eric T.
# 18  AfZPx4piTmg9dqZpYgYTgg  SrvYGDFK_VAfyWjSPHx5fA    Mo Lynn G.
# 19  AfZPx4piTmg9dqZpYgYTgg  8ABVURCkGT2HlTh73fUbiw      Steve A.
# 20  AfZPx4piTmg9dqZpYgYTgg  vldVxBaVkujEO-sXv6iRpw    Lillian L.
# 21  QaDOWy4-11982JWIxpImNQ  dx2KLT-B3IIgaW6H9nOe-w     Emilie R.
# 22  QaDOWy4-11982JWIxpImNQ  gn4fplNjeHUs_kutOYgtgA    Tanaiya W.
# 23  QaDOWy4-11982JWIxpImNQ  jQveoxxClSrkeyDnpHEX9g       Sara Y.
# 24  qXuUBEaib4caLC6WCPhBjA  p3BeEUskiiFTsiPvxo4HGw      Randy T.
# 25  qXuUBEaib4caLC6WCPhBjA  bIC3B9ODGU0afnfxMIdNtQ   Samantha D.
# 26  qXuUBEaib4caLC6WCPhBjA  4RspF42_KciMAPUTYojfkg       Jenn L.
# 27  k17DEW9TqRZf6EFSc49OsA  SqVUNVeYJblyoUz4e-Fiqw     Joseph T.
# 28  k17DEW9TqRZf6EFSc49OsA  lE-ydWWjL8GFeCq5OEcMDQ      Anita V.
# 29  k17DEW9TqRZf6EFSc49OsA  IOIeFGUy3F5oeSszVoJpcg     Jackie S.
#
#     review_rating                                        review_text
# 0               4  I loved the coffee to-go stand here. So glad I...
# 1               1  Clearly the owners/ management of this establi...
# 2               4  Oh my goodness this place was delicious! The r...
# 3               5  Perfect chill spot to catch up with a friend! ...
# 4               5  This place lives up to the hype. \n\nI tried a...
# 5               5  Adeni Chai (5) - very interesting and flavorfu...
# 6               5  Food (5/5): We ordered the caramel cake and th...
# 7               4  This bakery is situated in the heart of Willia...
# 8               4  Vegan cheesecake is non-dairy \nDelicious with...
# 9               5  I think this is one of the most underrated bre...
# 10              5  Wow... came across this cafe after a meeting a...
# 11              5  Adorable, authentic and convenient. Had a morn...
# 12              5  Coffee shop is a solid spot to grab and go or ...
# 13              4  This is a solid place to get some work done. I...
# 14              4  The avo toast was incredible - the feta and fr...
# 15              5  Run to this place NOW. Really amazing food wit...
# 16              4  Really cute spot in Greenpoint that serves ben...
# 17              5  Upon entering Acre in Greenpoint, confusion ha...
# 18              5  Listen.  This guy use to work for Peter Pan Do...
# 19              5  Absolutely great donuts!\n\nStop by here whene...
# 20              4  I'm only here for the rainbow donut, reminisce...
# 21              5  The food and the service were impeccable. We h...
# 22              5  I love the food and dranks there and I had the...
# 23              5  Vegan restaurant! In Williamsburg, \nThis plac...
# 24              5  Got a yuzu mousse cake here. Called 2 days bef...
# 25              3  One of my favorite types of desserts are the o...
# 26              4  Love this cute little dessert cafe in Williams...
# 27              4  Picked up some pastries for my wife for Valent...
# 28              1  My husband and I went to Bakeri for sweet trea...
# 29              1  Love their sweets and breakfast seemed like a ...

# %% [markdown]
# Pickle dataframes for future analysis.

# %%
# pickle df
business_df.to_pickle("./data/business_df.pkl")
review_df.to_pickle("./data/reviews_df.pkl")
