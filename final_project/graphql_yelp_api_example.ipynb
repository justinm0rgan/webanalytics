# %% [markdown]
# # Querying Yelp using GraphQL
# This is a beta program, but contrary to the other Yelp APIs, allows us to completely customize our querys, only obtaining the data we'll need for our analysis.
#
# Below is an example of how to utilize the `GraphQL` Yelp API to query 10 coffee shops in Brooklyn 11222 postal code.
#
# For detailed instructions please reference [Getting Started with Yelp GraphQL](https://docs.developer.yelp.com/docs/graphql-intro)

# %%
# import packages
import requests
import pandas as pd
import sys
sys.path.append('src') # add src folder to path

# import api key
from config import YELP_API

# %% [markdown]
# First we need to set our `headers` and `url`.<br>
# The API key needs to be approved for beta use, so prior to making any queries, goto the `Manage Account` section of your Yelp profile and approve for beta use.

# %%
# set up headers and access token
headers = {
    "Authorization": f"Bearer {YELP_API}",
    "Content-Type": "application/json"
}

# set url
url = "https://api.yelp.com/v3/graphql"

# %% [markdown]
# Next we perform the business query.<br>
# We don't want to query the reviews yet, because we have a **one-to-many relationship**, meaning we will have multiple reviews for each business (limiting to 5 in this demo).

# %%
# basic query
businesses_query = """
{
  search(location: "Brooklyn 11222", categories: "coffee", limit: 75) {
    business {
      id
      name
      rating
      review_count
    }
  }
}
"""

# %% [markdown]
# We make the API call with the `requests` package passing the query and the headers for authentication.<br>
# After this we convert the response to json, this will allow us to smoothly parse into lists and eventually dataframes.

# %%
# api call to fetch businesses
response = requests.post(url, json={"query": businesses_query}, headers=headers)
data = response.json()

# %%
# extract info
businesses = data["data"]["search"]["business"]

# data storage lists
business_data = []
review_data = []

# iterate over the businesses and fetch their reviews
for business in businesses:
    # fetch reviews for the current business
    reviews_query = f"""
    {{
      business(id: "{business['id']}") {{
        reviews(limit: 5) {{
          user {{
            name
            id
          }}
          rating
          text
        }}
      }}
    }}
    """
    # api call to fetch reviews
    reviews_response = requests.post(url, json={"query": reviews_query}, headers=headers)
    reviews_data = reviews_response.json()
    
    # extract info
    reviews = reviews_data["data"]["business"]["reviews"]

    # store business data
    business_data.append({
        "business_id": business["id"],
        "business_name": business["name"],
        "rating": business["rating"],
        "review_count": business["review_count"]
    })

    # store review data
    for review in reviews:
        review_data.append({
            "business_id": business["id"],
            "review_user_id":review["user"]["id"],
            "review_user": review["user"]["name"],
            "review_rating": review["rating"],
            "review_text": review["text"]
        })

# %% [markdown]
# Create two dataframes:
# - one for businesses
# - one for reviews
#
# Having separate dataframes will allow us to explore the **one-to-many** relationship between business and reviews.

# %%
# business df
business_df = pd.DataFrame(business_data)

# reviews df
review_df = pd.DataFrame(review_data)

# %% [markdown]
# Look at contents

# %%
business_df
# Out:
#                business_id                       business_name  rating  \
# 0   1Q3oaJahyGRogDWgpo7PIw                         Five Leaves     4.0
# 1   kpxXi23lUQkeJQH-2BtzDw                        Qahwah House     4.5
# 2   AfZPx4piTmg9dqZpYgYTgg             Moe's Doughs Donut Shop     4.5
# 3   YpGxtJy9ErnjfGG6DXy5uA                         Coffee Shop     4.5
# 4   VdAVjghEq_Zl-DDte0mjrw                                ACRE     4.5
# 5   s1pJHjoce-IbHQiCe4mA3w             Martha's Country Bakery     4.5
# 6   QaDOWy4-11982JWIxpImNQ              Little Choc Apothecary     4.5
# 7   UpPXAjKc-CyuCg72chwd3A                    Lella Alimentari     4.5
# 49  nLMJL4p7k4jNO4qLMc1wNg                                 Leo     4.0
#
#     review_count
# 0           1725
# 1            355
# 2            374
# 3            376
# 4            109
# 5            994
# 6            546
# 7            237
# 8            413
# 9            407
# 10           250
# 11           121
# 12           125
# 13            27
# 14           236
# 15           581
# 16            89
# 17           488
# 18           336
# 19           128
# 20           288
# 21           261
# 22           157
# 23           302
# 24           431
# 25           528
# 26           169
# 27           246
# 28           289
# 29           599
# 30            52
# 31            55
# 32           103
# 33            50
# 34           108
# 35            61
# 36           127
# 37            16
# 38           143
# 39           345
# 40           588
# 41            30
# 42            39
# 43           271
# 44           207
# 45            10
# 46           375
# 47            60
# 48            42
# 49            97

# %%
review_df
# Out:
#                 business_id          review_user_id  review_user  \
# 0    1Q3oaJahyGRogDWgpo7PIw  FvHYaxYF6mAw67dv_z35Rg       Ava B.
# 1    1Q3oaJahyGRogDWgpo7PIw  Sk9smcO5GeU1rY91DrFVew  Marykate M.
# 2    1Q3oaJahyGRogDWgpo7PIw  2M2GdA9HzcXI5cqECZDqgg    Brandi I.
# 3    kpxXi23lUQkeJQH-2BtzDw  lGZ1juew09lxLRDYAmdtjg    Sophia C.
# 4    kpxXi23lUQkeJQH-2BtzDw  zeTbYRLUK70R_3thy_L26A      Theo W.
# ..                      ...                     ...          ...
# 145  U1exuSaIwTwpjxvlrKeftg  6iJroP8frO-EEjjA9p9rjQ     Lucia P.
# 146  U1exuSaIwTwpjxvlrKeftg  NT5PIrm_5PMIvhKThayOIg     Katey G.
# 147  nLMJL4p7k4jNO4qLMc1wNg  HGUyWBhs0Jnmif7NZWKYrg     Julia H.
# 148  nLMJL4p7k4jNO4qLMc1wNg  wsdtHpgw45hpju4mREenoQ    Andrew T.
# 149  nLMJL4p7k4jNO4qLMc1wNg  3Ypn6ko0ctadij2sCaickQ      Jade B.
#
#      review_rating                                        review_text
# 0                4  I loved the coffee to-go stand here. So glad I...
# 1                1  Clearly the owners/ management of this establi...
# 2                4  Oh my goodness this place was delicious! The r...
# 3                5  Perfect chill spot to catch up with a friend! ...
# 4                5  This place lives up to the hype. \n\nI tried a...
# ..             ...                                                ...
# 145              5  I walked by this cafe while walking around the...
# 146              5  This is a beautiful little cafe where they met...
# 147              4  I pass by Leo almost every day and it's always...
# 148              5  DELICIOUS. I got a recommendation from a frien...
# 149              1  I've been to Leo several times now and each ti...
#
# [150 rows x 5 columns]

# %%
review_df.groupby('review_user_id').size().sort_values(ascending=False)
# Out:
# review_user_id
# bd0okEGblYceUqC9f9uTcg    4
# HGUyWBhs0Jnmif7NZWKYrg    3
# jQveoxxClSrkeyDnpHEX9g    3
# P7NHWUJlApHDaBlT-vFceg    2
# -yEhhXT6URxh_yxHko5Gzg    2
#                          ..
# JPH-WOKa6EBMlpBGLIPuiw    1
# JI4imSXT0MINFMzeu5aAkw    1
# JC7Q8D6l_oPyhyIkV_d-7g    1
# IOIeFGUy3F5oeSszVoJpcg    1
# zmUFr36jkcP2M7qLRHuoWA    1
# Length: 138, dtype: int64

# %% [markdown]
# Pickle dataframes for future analysis.

# %%
# pickle df
business_df.to_pickle("./data/business_df.pkl")
review_df.to_pickle("./data/reviews_df.pkl")
